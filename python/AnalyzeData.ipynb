# %% [markdown]
# __By: Paula Alvarez, Victor Camero, Daniela Lavanderas, Fernanda Vásquez__
#
# # Analyze

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
filter_dataset = pd.read_csv("../data/filtered_data_elpino.csv", delimiter=';')
filter_dataset.head(3)
# Out:
#                          Diag 01 Principal (cod+des)  \
# 0            A41.8 - Otras septicemias especificadas
# 1               U07.1 - COVID-19, virus identificado
# 2  K56.5 - Adherencias [bridas] intestinales con ...
#
#                      Diag 02 Secundario (cod+des)  \
# 0  B37.6 - Endocarditis debida a candida (I39.8*)
# 1           J12.8 - Neumonía debida a otros virus
# 2                           R57.2 - Shock séptico
#
#                         Diag 03 Secundario (cod+des)  \
# 0  I39.8 - Endocarditis, válvula no especificada,...
# 1                                     R06.0 - Disnea
# 2                        R57.1 - Choque hipovolémico
#
#                         Diag 04 Secundario (cod+des)  \
# 0            N10 - Nefritis tubulointersticial aguda
# 1                                          R05 - Tos
# 2  J80 - Síndrome de dificultad respiratoria del ...
#
#                         Diag 05 Secundario (cod+des)  \
# ...

# %%
filter_dataset.shape
# Out:
# (14279, 68)

# %%
umbral = int(0.90 * filter_dataset.shape[0])  
# Eliminar columnas con menos de "umbral" valores no nulos
clean_data = filter_dataset.dropna(axis=1, thresh=umbral)
clean_data.head()
# Out:
#                          Diag 01 Principal (cod+des)  \
# 0            A41.8 - Otras septicemias especificadas
# 1               U07.1 - COVID-19, virus identificado
# 2  K56.5 - Adherencias [bridas] intestinales con ...
# 3  K76.8 - Otras enfermedades especificadas del h...
# 4  T81.0 - Hemorragia y hematoma que complican un...
#
#                         Diag 02 Secundario (cod+des)  \
# 0     B37.6 - Endocarditis debida a candida (I39.8*)
# 1              J12.8 - Neumonía debida a otros virus
# 2                              R57.2 - Shock séptico
# 3                              K66.1 - Hemoperitoneo
# 4  Y83.2 - Operación quirúrgica con anastomosis, ...
#
#                        Proced 01 Principal (cod+des)  \
# 0  86.28 - DESBRIDAMIENTO HERIDA,INFECCION O QUEM...
# 1                      31.1 - TRAQUEOSTOMIA TEMPORAL
# 2  86.22 - DESBRIDAMIENTO HERIDA,INFECCION O QUEM...
# 3                           54.19 - LAPAROTOMIA.OTRA
# ...

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14279 entries, 0 to 14278
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Diag 01 Principal (cod+des)     14279 non-null  object
#  1   Diag 02 Secundario (cod+des)    13084 non-null  object
#  2   Proced 01 Principal (cod+des)   14279 non-null  object
#  3   Proced 02 Secundario (cod+des)  14147 non-null  object
#  4   Proced 03 Secundario (cod+des)  13942 non-null  object
#  5   Proced 04 Secundario (cod+des)  13685 non-null  object
#  6   Proced 05 Secundario (cod+des)  13333 non-null  object
#  7   Edad en años                    14279 non-null  int64
#  8   Sexo (Desc)                     14279 non-null  object
#  9   GRD                             14279 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ MB

# %%
clean_data.shape
# Out:
# (14279, 10)

# %%
clean_data.isnull().sum()
# Out:
# Diag 01 Principal (cod+des)          0
# Diag 02 Secundario (cod+des)      1195
# Proced 01 Principal (cod+des)        0
# Proced 02 Secundario (cod+des)     132
# Proced 03 Secundario (cod+des)     337
# Proced 04 Secundario (cod+des)     594
# Proced 05 Secundario (cod+des)     946
# Edad en años                         0
# Sexo (Desc)                          0
# GRD                                  0
# dtype: int64

# %%
clean_data
