# %% [markdown]
# By: __Paula Alvarez, Victor Camero, Daniela Lavanderas, Fernanda Vásquez__
#
# # Model IA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read File of Pino Hospital
